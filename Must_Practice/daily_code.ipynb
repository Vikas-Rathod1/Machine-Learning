# %%
import pandas as pd
import numpy as np

# %%
#creating dtaframe 
df = pd.DataFrame({'AA':[1,2,3,45,2,5],'BB':[2,3,2,4,2,5],'CC':[10,3,12,9,12,62]})
df
# Out:
#    AA  BB  CC
# 0   1   2  10
# 1   2   3   3
# 2   3   2  12
# 3  45   4   9
# 4   2   2  12
# 5   5   5  62

# %% [markdown]
# # 2. How to create a series from a list, numpy array and dict?

# %%
df=['vikas','viaks','sammmer','kinal','karan','vikram']
#df = pd.Series(['vikas','viaks','sammmer','kinal','karan','vikram'])
df1  = pd.Series(df)
df1
# Out:
# 0      vikas
# 1      viaks
# 2    sammmer
# 3      kinal
# 4      karan
# 5     vikram
# dtype: object

# %%
type(df)
type(df1)
# Out:
# pandas.core.series.Series

# %%
df = np.arange(26)
df2 =pd.Series(df)
mydict = dict(zip(df1, df2))
mydict
# Out:
# {'karan': 4, 'kinal': 3, 'sammmer': 2, 'viaks': 1, 'vikas': 0, 'vikram': 5}

# %%
read =pd.read_csv("/home/vikas/Downloads/data/college.csv")
read1 = read.copy()
read1.head(10)
# Out:
#                                 INSTNM            CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University          Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham      Birmingham     AL   0.0      0.0
# 2                   Amridge University      Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville      Huntsville     AL   0.0      0.0
# 4             Alabama State University      Montgomery     AL   1.0      0.0
# 5            The University of Alabama      Tuscaloosa     AL   0.0      0.0
# 6    Central Alabama Community College  Alexander City     AL   0.0      0.0
# 7              Athens State University          Athens     AL   0.0      0.0
# 8      Auburn University at Montgomery      Montgomery     AL   0.0      0.0
# 9                    Auburn University          Auburn     AL   0.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY         ...          \
# ...

# %%
s1 = read1['CITY'].head(10)
s1
# Out:
# 0            Normal
# 1        Birmingham
# 2        Montgomery
# 3        Huntsville
# 4        Montgomery
# 5        Tuscaloosa
# 6    Alexander City
# 7            Athens
# 8        Montgomery
# 9            Auburn
# Name: CITY, dtype: object

# %%
s2 =read1['SATVRMID'].head(10)
s2
# Out:
# 0    424.0
# 1    570.0
# 2      NaN
# 3    595.0
# 4    425.0
# 5    555.0
# 6      NaN
# 7      NaN
# 8    486.0
# 9    575.0
# Name: SATVRMID, dtype: float64

# %%
pd.concat([s1,s2],axis=1)
# Out:
#              CITY  SATVRMID
# 0          Normal     424.0
# 1      Birmingham     570.0
# 2      Montgomery       NaN
# 3      Huntsville     595.0
# 4      Montgomery     425.0
# 5      Tuscaloosa     555.0
# 6  Alexander City       NaN
# 7          Athens       NaN
# 8      Montgomery     486.0
# 9          Auburn     575.0
