# %%
import seaborn as nsn
# %matplotlib inline

# %%
tips = nsn.load_dataset('tips')
tips.head(12)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4

# %%
iris = nsn.load_dataset('iris')
iris.head(20)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %% [markdown]
# # distplot

# %%
nsn.distplot(tips['total_bill'])

# %%
nsn.distplot(tips['total_bill'],vertical = True)

# %%
nsn.distplot(iris['sepal_width'])

# %%
nsn.distplot(tips['total_bill'],kde = False)

# %%
nsn.distplot(tips['total_bill'],kde = False,bins =50)

# %% [markdown]
# # jointplot

# %%
nsn.jointplot(x= 'total_bill',y = 'tip',data= tips,kind = 'kde')

# %%
nsn.jointplot(x= 'total_bill',y = 'tip',data= tips,kind = 'scatter')

# %%
nsn.jointplot(x= 'total_bill',y = 'tip',data= tips,kind = 'reg')

# %%
nsn.jointplot(x= 'total_bill',y = 'tip',data= tips,kind = 'hex')

# %% [markdown]
# # pairplot

# %%
nsn.pairplot(iris)

# %%
nsn.pairplot(tips)

# %%
nsn.pairplot(tips,hue = 'time',palette = 'Blues_')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda/lib/python3.6/site-packages/seaborn/palettes.py in color_palette(palette, n_colors, desat)
#     176             try:
# --> 177                 palette = mpl_palette(palette, n_colors)
#     178             except ValueError:
#
# ~/anaconda/lib/python3.6/site-packages/seaborn/palettes.py in mpl_palette(name, n_colors)
#     405     else:
# --> 406         cmap = mpl.cm.get_cmap(name)
#     407         if cmap is None:
#
# ~/anaconda/lib/python3.6/site-packages/matplotlib/cm.py in get_cmap(name, lut)
#     168             "Colormap %s is not recognized. Possible values are: %s"
# --> 169             % (name, ', '.join(sorted(cmap_d))))
#     170
#
# ...

# %%
nsn.pairplot(tips,hue = 'time',palette = 'PuRd_r')

# %%
nsn.kdeplot(tips['total_bill'])

# %%
nsn.kdeplot(tips['tip'])

# %% [markdown]
# # Categorical Data Plots

# %%
import seaborn as sb
# %matplotlib inline

# %%
v  = sb.load_dataset('tips')
v.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
sb.barplot(x= 'size',y = 'sex',data= tips)

# %%
sb.barplot(x= 'tip',y = 'smoker',data= tips)

# %%
sb.barplot(x = 'sex',y = 'total_bill',data = tips)

# %%
import numpy as np
sb.barplot(x= 'sex',y = 'total_bill',data = tips,estimator = np.std)

# %%
sb.barplot(x= 'sex',y = 'total_bill',data = tips,estimator= np.mean)

# %%
sb.barplot(x= 'sex',y = 'total_bill',data = tips,estimator = np.max)

# %% [markdown]
# # countplot

# %%
sb.countplot(x = 'sex',data = tips)

# %%
sb.countplot(x= 'sex',y = 'total_bill',data = tips) # it take at a time one value either x or y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-80283e689cee> in <module>()
# ----> 1 sb.countplot(x= 'sex',y = 'total_bill',data = tips) # it take at a time one value either x or y
#
# ~/anaconda/lib/python3.6/site-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3331         y = x
#    3332     elif x is not None and y is not None:
# -> 3333         raise TypeError("Cannot pass values for both `x` and `y`")
#    3334     else:
#    3335         raise TypeError("Must pass values for either `x` or `y`")
#
# TypeError: Cannot pass values for both `x` and `y`

# %% [markdown]
# # boxplot and violinplot

# %%
sb.boxplot(x= 'sex',y = 'size',data = tips,palette = 'RdYlBu_r')

# %%
sb.boxplot(x = 'size',y = 'sex',data = tips,palette = 'rainbow')

# %%
sb.boxplot(data = tips,palette = 'rainbow',orient = 'h')

# %%
sb.boxplot(data=tips,palette = 'rainbow',orient = 'v')

# %%
sb.boxplot(x= 'size',y = 'sex',data =  tips, palette = 'rainbow',hue = 'smoker')

# %%
sb.violinplot(x= 'size',y = 'sex',data =  tips, palette = 'rainbow',hue = 'smoker')

# %%
sb.violinplot(x= 'size',y = 'total_bill',data =tips,palette = 'BrBG_r',hue = 'tip' )

# %%
sb.violinplot(x= 'size',y = 'total_bill',data =tips,palette = 'BrBG_r',hue = 'day' )

# %% [markdown]
# # stripplot and swarmplot

# %%
sb.stripplot(x= 'size',y = 'total_bill',data =tips,palette = 'BrBG_r',hue = 'day' )

# %%
sb.stripplot(x= 'day',y = 'total_bill',data = tips,jitter= True)

# %%
sb.stripplot(x= 'day',y = 'total_bill',data = tips,jitter= False)

# %%
sb.stripplot(x= 'day',y = 'total_bill',data = tips,
             jitter= True,hue = 'sex',palette = 'winter_r')

# %%
sb.stripplot(x= 'day',y = 'total_bill',data = tips,
             jitter= True,
             hue = 'sex',palette = 'winter_r',
             split = True)
# Out:
# /home/vikas/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:2567: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sb.swarmplot(x= 'day',y = 'total_bill',data = tips,hue = 'sex',palette = 'winter_r')

# %%
sb.stripplot(x= 'day',y = 'total_bill',data = tips,jitter= True,
             hue = 'sex',palette = 'winter_r',split = True)
# Out:
# /home/vikas/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:2567: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Combining Categorical Plots¶

# %%
sb.violinplot(x= 'sex', y = 'total_bill'
              ,data = tips,palette = 'rainbow')

# %%
sb.swarmplot(x= 'sex', y = 'total_bill'
              ,data = tips,palette = 'rainbow')

# %%
sb.violinplot(x= 'sex', y = 'total_bill'
              ,data = tips,palette = 'rainbow')
sb.swarmplot(x= 'sex', y = 'total_bill'
              ,data = tips,palette = 'rainbow')

# %%
sb.violinplot(x= 'sex', y = 'total_bill'
              ,data = tips,palette = 'rainbow')
sb.swarmplot(x= 'sex', y = 'total_bill',data = tips,palette = 'rainbow',
             color = 'black')

# %%
sb.swarmplot(x= 'sex', y = 'total_bill',data = tips,palette = 'rainbow',
             color = 'black',size = 3)

# %%
sb.violinplot(x= 'sex', y = 'total_bill'
              ,data = tips,palette = 'rainbow')
sb.swarmplot(x= 'sex', y = 'total_bill',data = tips,palette = 'rainbow',
             color = 'black',size = 3)

# %%
sb.factorplot(x = 'sex',y = 'total_bill',data = tips,kind = 'point')

# %%
sb.factorplot(x = 'sex',y = 'total_bill',data = tips,kind = 'count')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-e0146e726183> in <module>()
# ----> 1 sb.factorplot(x = 'sex',y = 'total_bill',data = tips,kind = 'count')
#
# ~/anaconda/lib/python3.6/site-packages/seaborn/categorical.py in factorplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, size, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3463             x_, y_, orient = x, x, "v"
#    3464         else:
# -> 3465             raise ValueError("Either `x` or `y` must be None for count plots")
#    3466     else:
#    3467         x_, y_ = x, y
#
# ValueError: Either `x` or `y` must be None for count plots

# %%
sb.factorplot(y = 'total_bill',data = tips,kind = 'count')

# %%
sb.factorplot(x = 'tip',y = 'total_bill',data = tips,kind = 'strip',split = True)

# %% [markdown]
# # Matrix Plots

# %%
import seaborn as sb
# %matplotlib  inline

# %%
v = sb.load_dataset('flights')
v

# %%
tips.head(20)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
tips.corr()
#sb.load_dataset('tips').head(10)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sb.heatmap(tips.corr())

# %%
sb.heatmap(tips.corr(),cmap = 'coolwarm',annot =True)

# %%
tips.pivot_tabel(values = 'tip',index= 'size',columns = 'sex')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-7e7c978450b0> in <module>()
#       5
#       6
# ----> 7 tips.pivot_tabel(values = 'tip',index= 'size',columns = 'sex')
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'pivot_tabel'

# %%
tips.pivot_table(values = 'tip',index= 'size',columns = 'sex')
# Out:
# sex       Male    Female
# size
# 1     1.920000  1.276667
# 2     2.614184  2.528448
# 3     3.476667  3.250000
# 4     4.172143  4.021111
# 5     3.750000  5.140000
# 6     5.850000  4.600000

# %%
v.pivot_table(values ='passengers',index= 'month',columns = 'year')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-af74bbc6202e> in <module>()
# ----> 1 v.pivot_table(values ='passengers',index= 'month',columns = 'year')
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#     110         for i in values:
#     111             if i not in data:
# --> 112                 raise KeyError(i)
#     113
#     114         to_filter = []
#
# KeyError: 'passengers'

# %%
x = v.pivot_table(values ='passengers',index= 'month',columns = 'year')
sb.heatmap(x)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-503baaa520bf> in <module>()
# ----> 1 x = v.pivot_table(values ='passengers',index= 'month',columns = 'year')
#       2 sb.heatmap(x)
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#     110         for i in values:
#     111             if i not in data:
# --> 112                 raise KeyError(i)
#     113
#     114         to_filter = []
#
# KeyError: 'passengers'

# %%
sb.heatmap(x,cmap = 'magma',linecolor = 'yellow',lw = 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-cc36675602a0> in <module>()
# ----> 1 sb.heatmap(x,cmap = 'magma',linecolor = 'yellow',lw = 2)
#
# NameError: name 'x' is not defined

# %% [markdown]
# # Style and Color

# %%
import seaborn as s
# %matplotlib inline

# %%
b = s.load_dataset('tips')
b.head(20)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
s.countplot(x= 'total_bill',data = tips)

# %%
s.countplot(x= 'sex',data = tips)

# %%
s.set_style('black')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-990ce5339b40> in <module>()
# ----> 1 s.set_style('black')
#
# ~/anaconda/lib/python3.6/site-packages/seaborn/rcmod.py in set_style(style, rc)
#     285
#     286     """
# --> 287     style_object = axes_style(style, rc)
#     288     mpl.rcParams.update(style_object)
#     289
#
# ~/anaconda/lib/python3.6/site-packages/seaborn/rcmod.py in axes_style(style, rc)
#     167         styles = ["white", "dark", "whitegrid", "darkgrid", "ticks"]
#     168         if style not in styles:
# --> 169             raise ValueError("style must be one of %s" % ", ".join(styles))
#     170
#     171         # Define colors here
#
# ValueError: style must be one of white, dark, whitegrid, darkgrid, ticks

# %%
s.set_style('ticks') ########white, dark, whitegrid, darkgrid, ticks
s.countplot(x= 'sex',data = tips)

# %%
s.countplot(x= 'sex',data = tips)
s.set_style('darkgrid')

# %%
s.countplot(x= 'sex',data = tips)
s.set_style('dark')

# %% [markdown]
# # Spine Removal

# %%
s.countplot(x= 'size',data = tips)
s.despine(right = True)

# %%
s.countplot(x= 'size',data = tips)
s.despine(right = False)

# %%
s.countplot(x= 'size',data = tips)
s.despine(left = True)

# %%
s.countplot(x= 'size',data = tips)
s.despine(bottom = True)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (16,10))
s.countplot(x= 'tip',data = tips)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (16,10))
s.stripplot(x= 'sex',y = 'size',data = tips)

# %%
s.lmplot(x= 'size',y = 'tip',data = tips,size = 2,aspect = 4)

# %%
s.set_context('poster',font_scale =2)
s.countplot(x = 'sex',data = tips,palette ='rainbow')

# %%
s.set_context('poster',font_scale =2)
s.countplot(x = 'size',data = tips,palette ='rainbow')
