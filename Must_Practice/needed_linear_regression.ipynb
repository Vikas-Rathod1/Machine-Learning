# %% [markdown]
# # Normal Equation
# #https://medium.com/@dikshitkathuria1803/normal-equation-using-python-5993454fbb41

# %%
import numpy  as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
x  = np.array([1,2,3,4,5,6])
y = np.array([1,2,3,2,4,3])

# %%
#np.scatter(x,y)
plt.plot(x,y,'H')
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0,0.5,'Y')

# %%
# df.DataFrame({Location	PovPct	Brth15to17	Brth18to19	ViolCrime	TeenBrth
# 'Alabama':[20.1,31.5,88.7,11.2,54.5]
# 'Alaska':[7.1,18.9,73.7,9.1	39.5]
# 'Arizona':[16.1,35,102.5,10.4,61.2]
# 'Arkansas'[14.9,31.6,101.7,10.4,59.9]
# 'California'[16.7,22.6,69.1,11.2,41.1]
# 'Colorado'[8.8,26.2,79.1,5.8,47]
# 'Connecticut'[9.7,14.1,45.1,4.6,25.8]
# 'Delaware'[10.3	24.7,77.8,3.5,46.3]
# 'District_of_Columbia'[22,44.8,101.5,65,69.1]
# 'Florida'[16.2,23.2,78.4,7.3,44.5]
# 'Georgia'[12.1,31.4,92.8,9.5,55.7]
# 'Hawaii'[10.3,17.7,66.4,4.7,38.2]
# 'Idaho'[14.5,18.4,69.1,4.1,39.1]
# 'Illinois'[12.4,23.4,70.5,10.3,42.2]
# 'Indiana'[9.6,22.6,78.5,8,44.6]
# 'Iowa'[12.2,16.4,55.4,1.8,32.5]
# 'Kansas'[10.8,21.4,74.2,6.2,43]
# 'Kentucky'[14.7,26.5,84.8,7.2,51]
# 'Louisiana'[19.7,31.7,96.1,17,58.1]
# 'Maine'[11.2,11.9,45.2,2,25.4]
# 'Maryland'[10.1,20,5,9.6,11.8,35.4]
# 'Massachusetts'[11,12.5,39.6,3.6,23.3]
# 'Michigan'[12.2,18,60.8,8.5,34.8]
# 'Minnesota'[9.2,14.2,47.3,3.9,27.5]
# 'Mississippi'[23.5,37.6,103.3,12.9,64.7]
# 'Missouri'[9.4,22.2,76.6,8.8,44.1]
# 'Montana'[15.317.8,63.3,3,36.4]
# 'Nebraska'[9.6,18.3,64.2,2.9,37]
# 'Nevada'[11.1,28,96.7,10.7,53.9]
# 'New_Hampshire'[5.3,8.1,39,1.8,20]
# 'New_Jersey'[7.8,14.7,46.1,5.1,26.8]
# 'New_Mexico'[25.3,37.8,99.5,8.8,62.4]
# 'New_York'[16.5,15.7,50.1,8.5,29.5]
# 'North_Carolina'[12.6,28.6,89.3,9.4,52.2]
# 'North_Dakota'[12,11.7,48.7,0.9,7.2]
# 'Ohio'[11.520.1,69.4,5.4,39.5]
# 'Oklahoma'[17.1,30.1,97.6,12.2,58]
# 'Oregon'[11.2,18.2,64.8,4.1,36.8]
# 'Pennsylvania'[12.2,17.2,53.7,6.3,31.6]
# 'Rhode_Island'[10.6,19.6,59,3.3,35.6]
# 'South_Carolina'[19.9,29.2,87.2,7.9,53]
# 'South_Dakota'[14.5,17.3,67.8,1.8,38]
# 'Tennessee'[15.5,28.2	94.2	10.6	54.3]
# 'Texas'[17.4	38.2	104.3	9	64.4]
# 'Utah'[8.4	17.8	62.4	3.9	36.8]
# 'Vermont'[10.3	10.4	44.4	2.2	24.2]
# 'Virginia'[10.2	19	66	7.6	37.6]
# 'Washington'[12.5	16.8	57.6	5.1	33]
# 'West_Virginia'[16.7	21.5	80.7	4.9	45.5]
# 'Wisconsin'[8.5	15.9	57.1	4.3	32.3]
# 'Wyoming'[12.2	17.7	72.1	2.1	39.9]
# })

# %%
import numpy as np 
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
read = pd.read_csv('https://newonlinecourses.science.psu.edu/stat462/sites/onlinecourses.science.psu.edu.stat462/files/data/poverty/index.txt',sep='\t')
read
# Out:
#                 Location  PovPct  Brth15to17  Brth18to19  ViolCrime  TeenBrth
# 0                Alabama    20.1        31.5        88.7       11.2      54.5
# 1                 Alaska     7.1        18.9        73.7        9.1      39.5
# 2                Arizona    16.1        35.0       102.5       10.4      61.2
# 3               Arkansas    14.9        31.6       101.7       10.4      59.9
# 4             California    16.7        22.6        69.1       11.2      41.1
# 5               Colorado     8.8        26.2        79.1        5.8      47.0
# 6            Connecticut     9.7        14.1        45.1        4.6      25.8
# 7               Delaware    10.3        24.7        77.8        3.5      46.3
# 8   District_of_Columbia    22.0        44.8       101.5       65.0      69.1
# 9                Florida    16.2        23.2        78.4        7.3      44.5
# 10               Georgia    12.1        31.4        92.8        9.5      55.7
# ...

# %%
read1 = read.copy()
read1
# Out:
#                 Location  PovPct  Brth15to17  Brth18to19  ViolCrime  TeenBrth
# 0                Alabama    20.1        31.5        88.7       11.2      54.5
# 1                 Alaska     7.1        18.9        73.7        9.1      39.5
# 2                Arizona    16.1        35.0       102.5       10.4      61.2
# 3               Arkansas    14.9        31.6       101.7       10.4      59.9
# 4             California    16.7        22.6        69.1       11.2      41.1
# 5               Colorado     8.8        26.2        79.1        5.8      47.0
# 6            Connecticut     9.7        14.1        45.1        4.6      25.8
# 7               Delaware    10.3        24.7        77.8        3.5      46.3
# 8   District_of_Columbia    22.0        44.8       101.5       65.0      69.1
# 9                Florida    16.2        23.2        78.4        7.3      44.5
# 10               Georgia    12.1        31.4        92.8        9.5      55.7
# ...

# %%
plt.scatter(x= 'PovPct in %',y = 'Brth15to17 in %',data = read)

# %%
sb.jointplot(x= 'PovPct',y = 'Brth15to17',data= read1,kind = 'scatter')

# %%
read1.plot.scatter(x='PovPct',y='Brth15to17',figsize=(16,10),lw =10)

# %% [markdown]
# Step 2: Calculate correlation coefficient

# %%
read1[['PovPct','Brth15to17','Brth18to19','ViolCrime','TeenBrth']].sum()
# Out:
# PovPct         669.0
# Brth15to17    1136.4
# Brth18to19    3673.0
# ViolCrime      400.6
# TeenBrth      2154.4
# dtype: float64

# %%
pearsoncorr =read1.corr(method='pearson')
coedt = pearsoncorr.loc['Brth15to17','PovPct']

# %% [markdown]
#  3.Calculate the coefficient of determination

# %%
coedt**2
# Out:
# 0.5333279627871963

# %%
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime
from sklearn import preprocessing
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("https://newonlinecourses.science.psu.edu/stat462/sites/onlinecourses.science.psu.edu.stat462/files/data/poverty/index.txt",index_col=0,sep = '\t')
df
# Out:
#                       PovPct  Brth15to17  Brth18to19  ViolCrime  TeenBrth
# Location
# Alabama                 20.1        31.5        88.7       11.2      54.5
# Alaska                   7.1        18.9        73.7        9.1      39.5
# Arizona                 16.1        35.0       102.5       10.4      61.2
# Arkansas                14.9        31.6       101.7       10.4      59.9
# California              16.7        22.6        69.1       11.2      41.1
# Colorado                 8.8        26.2        79.1        5.8      47.0
# Connecticut              9.7        14.1        45.1        4.6      25.8
# Delaware                10.3        24.7        77.8        3.5      46.3
# District_of_Columbia    22.0        44.8       101.5       65.0      69.1
# Florida                 16.2        23.2        78.4        7.3      44.5
# Georgia                 12.1        31.4        92.8        9.5      55.7
# Hawaii                  10.3        17.7        66.4        4.7      38.2
# ...

# %%
from sklearn.linear_model import LinearRegression,Lasso

# %%
df.shape
# Out:
# (51, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, Alabama to Wyoming
# Data columns (total 5 columns):
# PovPct        51 non-null float64
# Brth15to17    51 non-null float64
# Brth18to19    51 non-null float64
# ViolCrime     51 non-null float64
# TeenBrth      51 non-null float64
# dtypes: float64(5)
# memory usage: 2.4+ KB

# %%
df.describe()
# Out:
#           PovPct  Brth15to17  Brth18to19  ViolCrime   TeenBrth
# count  51.000000   51.000000   51.000000  51.000000  51.000000
# mean   13.117647   22.282353   72.019608   7.854902  42.243137
# std     4.277228    8.043499   18.975563   8.914131  12.318511
# min     5.300000    8.100000   39.000000   0.900000  20.000000
# 25%    10.250000   17.250000   58.300000   3.900000  33.900000
# 50%    12.200000   20.000000   69.400000   6.300000  39.500000
# 75%    15.800000   28.100000   87.950000   9.450000  52.600000
# max    25.300000   44.800000  104.300000  65.000000  69.100000

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.1,random_state = 9)
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((45, 4), (45,), (6, 4), (6,))

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred = lr.predict(X_test)

# %%
lr.score(X_test,y_test)
# Out:
# 0.99550568192927702

# %%
lr.coef_
# Out:
# array([ 0.08900083,  0.5513676 ,  0.40497043,  0.02385624])

# %%
ls = Lasso()
ls.fit(X_train,y_train)
# Out:
# Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
y_pred = ls.predict(X_test)
y_pred
# Out:
# array([ 61.85443065,  27.01811773,  35.57500697,  45.69484006,
#         31.70935841,  31.91065493])

# %%
ls.score(X_test,y_test)
# Out:
# 0.99660803913994123

# %% [markdown]
# # Start

# %%
from sklearn.linear_model import LinearRegression,Ridge

# %%
df.shape
# Out:
# (51, 5)

# %%
df.describe()
# Out:
#           PovPct  Brth15to17  Brth18to19  ViolCrime   TeenBrth
# count  51.000000   51.000000   51.000000  51.000000  51.000000
# mean   13.117647   22.282353   72.019608   7.854902  42.243137
# std     4.277228    8.043499   18.975563   8.914131  12.318511
# min     5.300000    8.100000   39.000000   0.900000  20.000000
# 25%    10.250000   17.250000   58.300000   3.900000  33.900000
# 50%    12.200000   20.000000   69.400000   6.300000  39.500000
# 75%    15.800000   28.100000   87.950000   9.450000  52.600000
# max    25.300000   44.800000  104.300000  65.000000  69.100000

# %%
y=df.loc[:,'Brth18to19']
x=df.loc[:,['Brth15to17','PovPct','ViolCrime','TeenBrth']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.1,random_state= 7)

# %%
x_train.shape,y_train.shape,y_test.shape,x_test.shape
# Out:
# ((45, 4), (45,), (6,), (6, 4))

# %%
algo1 = LinearRegression()
algo1.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred = algo1.predict(x_test)

y_pred
# Out:
# array([ 53.21322899,  88.05399528,  93.0872643 ,  96.39193274,
#         87.48268201,  45.76329411])

# %%
algo1.score(x_test,y_test)
# Out:
# 0.99601261543722708

# %%
ls = Lasso()
ls.fit(x_train,y_train)
# Out:
# Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
pred= ls.predict(x_test)
pred
# Out:
# array([ 54.55922816,  88.05466269,  93.5530355 ,  95.50001   ,
#         86.61428551,  47.5214867 ])

# %%
ls.score(x_test,y_test)
# Out:
# 0.99633054696774359

# %%
rd = Ridge()
rd.fit(x_train,y_train)
rd.predict(x_test)
rd.score(x_test,y_test)
# Out:
# 0.99613969251856094

# %%
y=df.loc[:,'PovPct']
x=df.loc[:,['Brth15to17','Brth18to19','ViolCrime','TeenBrth']]

# %% [markdown]
# # Case Study

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
read_train_data = pd.read_csv("/home/vikas/Downloads/data/case1/train_data.csv")
#read_test_data = pd.read_csv("/home/vikas/Downloads/data/case1/test.csv")

# %%
read_train_data
# Out:
#      Donut ID  Donut Estimator 1  Donut Area of cross section  \
# 0           1             317.61                       496.27
# 1           2             315.19                       538.85
# 2           3             317.44                       514.24
# 3           4             336.62                       562.98
# 4           5             331.76                       558.90
# 5           6             323.95                       554.18
# 6           7             348.63                       561.71
# 7           8             343.16                       522.48
# 8           9             333.50                       570.32
# 9          10             359.21                       625.14
# 10         11             353.73                       581.39
# 11         12             365.01                       616.67
# 12         13             343.00                       579.93
# 13         14             350.48                       589.33
# ...

# %%
read_test_data
# Out:
#      Donut ID  Donut Estimator 1  Donut Area of cross section  \
# 0           1             354.84                       512.67
# 1           2             284.50                       419.91
# 2           3             298.34                       450.13
# 3           4             302.40                       472.97
# 4           5             422.84                       726.44
# 5           6             338.34                       573.35
# 6           7             322.54                       508.52
# 7           8             294.22                       430.86
# 8           9             330.32                       576.22
# 9          10             349.89                       559.81
# 10         11             318.64                       497.98
# 11         12             363.19                       604.13
# 12         13             345.99                       587.11
# 13         14             319.13                       502.12
# ...

# %%
read_train_data.shape,read_test_data.shape
# Out:
# ((749, 13), (668, 13))

# %%
read_train_data.columns
# Out:
# Index(['Donut ID', 'Donut Estimator 1', 'Donut Area of cross section',
#        'Donut Area of circumference circle',
#        'Donut area of central hole / Donut Area of circumscribed circle',
#        'Donut  Estimator 2', 'Donut  Estimator 3', 'Donut  Estimator 4',
#        'Donut  Estimator 5', 'Donut volume Estimator 6', 'Location',
#        'Donut Density', 'Donut volume'],
#       dtype='object')

# %%
read_test_data.columns
# Out:
# Index(['Donut ID', 'Donut Estimator 1', 'Donut Area of cross section',
#        'Donut Area of circumference circle',
#        'Donut area of central hole / Donut Area of circumscribed circle',
#        'Donut Estimator 2', 'Donut Estimator 3', 'Donut Estimator 4',
#        'Donut Estimator 5', 'Donut volume Estimator 6', 'Location',
#        'Donut Density', 'Donut volume'],
#       dtype='object')

# %%
#read_train_data.describe(),
read_test_data.describe()
# Out:
#          Donut ID  Donut Estimator 1  Donut Area of cross section  \
# count  668.000000         668.000000                   668.000000
# mean   333.270958         392.332964                   762.221707
# std    193.478782          54.550914                   127.088277
# min      1.000000         284.500000                   406.540000
# 25%    165.750000         353.227500                   679.695000
# 50%    333.500000         381.855000                   769.925000
# 75%    500.250000         422.772500                   853.495000
# max    668.000000         688.450000                  1119.520000
#
#        Donut Area of circumference circle  \
# count                          668.000000
# mean                           840.392814
# std                             91.493476
# min                            632.080000
# 25%                            774.545000
# 50%                            831.195000
# 75%                            897.385000
# ...

# %%
read_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 749 entries, 0 to 748
# Data columns (total 13 columns):
# Donut ID                                                           749 non-null int64
# Donut Estimator 1                                                  749 non-null float64
# Donut Area of cross section                                        749 non-null float64
# Donut Area of circumference circle                                 749 non-null float64
# Donut area of central hole / Donut Area of circumscribed circle    749 non-null float64
# Donut  Estimator 2                                                 749 non-null float64
# Donut  Estimator 3                                                 749 non-null float64
# Donut  Estimator 4                                                 749 non-null float64
# Donut  Estimator 5                                                 749 non-null float64
# ...

# %%
read_train_data.columns
# Out:
# Index(['Donut ID', 'Donut Estimator 1', 'Donut Area of cross section',
#        'Donut Area of circumference circle',
#        'Donut area of central hole / Donut Area of circumscribed circle',
#        'Donut  Estimator 2', 'Donut  Estimator 3', 'Donut  Estimator 4',
#        'Donut  Estimator 5', 'Donut volume Estimator 6', 'Location',
#        'Donut Density', 'Donut volume'],
#       dtype='object')

# %%
read_test_data.head()
# Out:
#    Donut ID  Donut Estimator 1  Donut Area of cross section  \
# 0         1             354.84                       512.67
# 1         2             284.50                       419.91
# 2         3             298.34                       450.13
# 3         4             302.40                       472.97
# 4         5             422.84                       726.44
#
#    Donut Area of circumference circle  \
# 0                              703.84
# 1                              632.08
# 2                              701.23
# 3                              694.86
# 4                              806.40
#
#    Donut area of central hole / Donut Area of circumscribed circle  \
# 0                                               0.28
# 1                                               0.33
# 2                                               0.36
# 3                                               0.32
# 4                                               0.10
#
# ...

# %%
x=read_train_data.iloc[:,:12]

y=read_train_data.iloc[:,12:]

# %%
x
# Out:
#      Donut ID  Donut Estimator 1  Donut Area of cross section  \
# 0           1             317.61                       496.27
# 1           2             315.19                       538.85
# 2           3             317.44                       514.24
# 3           4             336.62                       562.98
# 4           5             331.76                       558.90
# 5           6             323.95                       554.18
# 6           7             348.63                       561.71
# 7           8             343.16                       522.48
# 8           9             333.50                       570.32
# 9          10             359.21                       625.14
# 10         11             353.73                       581.39
# 11         12             365.01                       616.67
# 12         13             343.00                       579.93
# 13         14             350.48                       589.33
# ...

# %%
y
# Out:
#      Donut volume
# 0            52.1
# 1            54.2
# 2            54.8
# 3            56.6
# 4            56.9
# 5            57.1
# 6            58.1
# 7            58.6
# 8            59.1
# 9            59.2
# 10           60.1
# 11           60.4
# 12           60.6
# 13           60.6
# 14           61.1
# 15           61.6
# 16           62.4
# 17           63.3
# 18           63.5
# 19           63.6
# 20           64.7
# 21           64.8
# 22           65.2
# 23           65.3
# 24           65.7
# 25           65.7
# 26           66.4
# 27           66.4
# 28           66.9
# 29           66.9
# ..            ...
# 719          96.0
# 720          96.7
# 721          97.0
# 722          97.0
# 723          97.0
# 724          97.0
# 725          98.0
# 726          98.0
# 727          98.0
# 728          98.1
# 729          99.0
# 730          99.0
# 731         100.0
# 732         100.0
# 733         101.0
# 734         101.9
# 735         102.0
# 736         103.0
# ...

# %%
# from sklearn.preprocessing import OneHotEncoder

# onehotencoder = OneHotEncoder(categorical_features = [11])

# x = onehotencoder.fit_transform(x).toarray()

# from sklearn.preprocessing import LabelEncoder
# labelencoder = LabelEncoder()
# OneHotEncoder().fit_transform(read_train_data)

# Categorical boolean mask
# categorical_feature_mask = x.dtypes==object# filter categorical columns using mask and turn it into a list
# categorical_cols = x.columns[categorical_feature_mask].tolist()


#from sklearn.preprocessing import LabelEncoder
#le = LabelEncoder()
# x[categorical_cols] = x[categorical_cols].apply(lambda col: le.fit_transform(col))

# %%
categorical_feature_mask = x.dtypes==object# filter categorical columns using mask and turn it into a list
categorical_cols = x.columns[categorical_feature_mask].tolist()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
x[categorical_cols] = x[categorical_cols].apply(lambda col: le.fit_transform(col))

# %%
x
# Out:
#      Donut ID  Donut Estimator 1  Donut Area of cross section  \
# 0           1             317.61                       496.27
# 1           2             315.19                       538.85
# 2           3             317.44                       514.24
# 3           4             336.62                       562.98
# 4           5             331.76                       558.90
# 5           6             323.95                       554.18
# 6           7             348.63                       561.71
# 7           8             343.16                       522.48
# 8           9             333.50                       570.32
# 9          10             359.21                       625.14
# 10         11             353.73                       581.39
# 11         12             365.01                       616.67
# 12         13             343.00                       579.93
# 13         14             350.48                       589.33
# ...

# %%
y
# Out:
#      Donut volume
# 0            52.1
# 1            54.2
# 2            54.8
# 3            56.6
# 4            56.9
# 5            57.1
# 6            58.1
# 7            58.6
# 8            59.1
# 9            59.2
# 10           60.1
# 11           60.4
# 12           60.6
# 13           60.6
# 14           61.1
# 15           61.6
# 16           62.4
# 17           63.3
# 18           63.5
# 19           63.6
# 20           64.7
# 21           64.8
# 22           65.2
# 23           65.3
# 24           65.7
# 25           65.7
# 26           66.4
# 27           66.4
# 28           66.9
# 29           66.9
# ..            ...
# 719          96.0
# 720          96.7
# 721          97.0
# 722          97.0
# 723          97.0
# 724          97.0
# 725          98.0
# 726          98.0
# 727          98.0
# 728          98.1
# 729          99.0
# 730          99.0
# 731         100.0
# 732         100.0
# 733         101.0
# 734         101.9
# 735         102.0
# 736         103.0
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.1,random_state=10)
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((674, 12), (674, 1), (75, 12), (75, 1))

# %%
lr  = LinearRegression()
lr.fit(x_train,y_train)
pred = lr.predict(x_test)
lr.score(x_test,y_test)
# Out:
# 0.88280364440111636

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,pred)
# Out:
# 10.31380933275268

# %%
lr = LinearRegression().fit(x_train, x_train)
# print("lr.coef_: {}".format(lr.coef_))
# print("lr.intercept_: {}".format(lr.intercept_))
# print("Training set score: {:.2f}".format(lr.score(x_train, y_train)))
print("Test set score: {:.1f}".format(lr.score(x_test, x_test)))
# Out:
# Test set score: 1.0

# %%
#print("Training set score: {:.7f}".format(lr.score(x_train, y_train)))
lr.score(x_train,y_train)
# Out:
# 0.84666024654342598

# %%
len(x_test),len(y_test)
# Out:
# (75, 75)

# %%
len(x_train),len(y_train)
# Out:
# (674, 674)

# %%
lr.intercept_
# Out:
# array([  1.30739863e-12,  -1.70530257e-13,   2.27373675e-13,
#         -1.13686838e-13,  -6.68076705e-14,   6.82121026e-13,
#          0.00000000e+00,   1.13686838e-13,   2.27373675e-13,
#          2.27373675e-13,  -3.33066907e-15,  -2.23820962e-13])

# %%
lr.coef_
# Out:
# array([[  1.00000000e+00,   3.45597228e-16,  -3.19363329e-16,
#           4.00625496e-16,  -1.58204097e-13,  -3.44938178e-16,
#          -4.90626412e-16,  -2.97958176e-16,  -2.25034275e-16,
#          -3.21276238e-16,   3.26299065e-15,  -8.17817655e-16],
#        [ -3.09136557e-17,   1.00000000e+00,  -3.88578059e-16,
#          -2.22044605e-16,   7.89368571e-14,   6.66133815e-16,
#           1.66533454e-16,  -1.38777878e-16,   0.00000000e+00,
#          -8.32667268e-17,   2.67147415e-16,   7.49400542e-16],
#        [ -1.42191772e-17,  -1.44328993e-15,   1.00000000e+00,
#          -3.33066907e-16,  -8.32667268e-17,   0.00000000e+00,
#           4.71844785e-16,   5.27355937e-16,  -1.38777878e-16,
#          -2.44596010e-16,   1.35785480e-14,   1.40512602e-16],
#        [  2.16754242e-16,   7.21644966e-16,  -1.32532874e-15,
#           1.00000000e+00,   1.45439216e-14,  -1.94017979e-16,
#           5.55111512e-17,  -1.11022302e-16,   5.55111512e-16,
# ...

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
afp = np.append(x_train['AFP'].values, x_test['AFP'].values)
std.fit(afp)

x_train[['AFP']] = std.transform(x_train['AFP'])
x_test[['AFP']] = std.transform(x_test['AFP'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AFP'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-966-03b5dde9f266> in <module>()
# ...
