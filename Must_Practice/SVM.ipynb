# %% [markdown]
# # Application SVM
#
# https://data-flair.training/blogs/applications-of-svm/

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
# %matplotlib inline

# %%
read = pd.read_csv("/home/vikas/Downloads/data/mushrooms.csv")
read
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# 5        e         x           y         y       t    a               f
# 6        e         b           s         w       t    a               f
# 7        e         b           y         w       t    l               f
# 8        p         x           y         w       t    p               f
# 9        e         b           s         y       t    a               f
# 10       e         x           y         y       t    l               f
# 11       e         x           y         y       t    a               f
# ...

# %% [markdown]
# # Fitting a support vector machine

# %%
from sklearn.svm import SVC
from sklearn.datasets.samples_generator import make_blobs

# %%
x,y = make_blobs(n_samples= 50,centers = 2,
               random_state = 0,cluster_std = 0.66)

# %%
#svc= SVC()
model = SVC(kernel='linear',C=1E10)
model
# Out:
# SVC(C=10000000000.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
model.fit(x,y)
# Out:
# SVC(C=10000000000.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
x
# Out:
# array([[ 1.34857079,  1.5936018 ],
#        [ 1.78917074,  1.70447741],
#        [ 1.47855498,  4.38409284],
#        [ 1.96236227,  4.16838287],
#        [ 2.09916889,  1.09729511],
#        [ 2.80727197,  0.08267862],
#        [ 3.29814698,  0.00814268],
#        [ 2.06219754,  2.07633819],
#        [ 2.03666725,  1.18036269],
#        [-0.14986825,  5.59129909],
#        [ 1.78826193,  5.09735803],
#        [ 0.14942514,  4.81693096],
#        [ 1.07853538,  4.55337459],
#        [ 1.4805414 ,  0.51562288],
#        [ 1.54679797,  3.81395841],
#        [ 1.18289476,  3.74008414],
#        [ 0.72063438,  4.10426751],
#        [ 2.320813  ,  0.445689  ],
#        [ 0.39033149,  2.99646166],
#        [ 0.90814564,  4.57478234],
#        [ 1.63661494,  0.65825449],
#        [ 2.29046934,  1.36400195],
#        [ 1.4564506 ,  0.93194762],
#        [ 1.61144363,  0.66035857],
#        [ 2.53646729,  0.98279238],
#        [ 2.47430813,  3.34390598],
#        [ 0.63989964,  4.01465829],
# ...

# %%
len(y),len(x),x.shape,y.shape
# Out:
# (50, 50, (50, 2), (50,))

# %%
#plt.plot(x,y,'r')
#plt.scatter(x,y,cmap='spring')

# %%
from sklearn.svm import SVC
from sklearn.datasets.samples_generator import make_blobs
x,y = make_blobs(n_samples= 50,centers = 2,
               random_state = 0,cluster_std = 0.66)
#svc= SVC()
model = SVC(kernel='linear',C=1E10)
model.fit(x,y)
#plt.plot(x,y,'o')
# Out:
# SVC(C=10000000000.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# # To motivate the need for kernels, let's look at some data that is not linearly separable:

# %%
# %maatplotlib notebbok
# Out:
# ERROR:root:Line magic function `%maatplotlib` not found.

# %%
import IPython
print(IPython.sys_info())
# Out:
# {'commit_hash': 'd86648c5d',
#  'commit_source': 'installation',
#  'default_encoding': 'UTF-8',
#  'ipython_path': '/home/vikas/anaconda/lib/python3.6/site-packages/IPython',
#  'ipython_version': '6.1.0',
#  'os_name': 'posix',
#  'platform': 'Linux-4.15.0-72-generic-x86_64-with-debian-stretch-sid',
#  'sys_executable': '/home/vikas/anaconda/bin/python',
#  'sys_platform': 'linux',
#  'sys_version': '3.6.3 |Anaconda, Inc.| (default, Oct 13 2017, 12:02:49) \n'
#                 '[GCC 7.2.0]'}

# %%
from sklearn.datasets.samples_generator import make_circles
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb
plt.style.use("ggplot")

# %%
x,y  = make_circles(100,factor=.1,noise=.1)
plt.scatter(x[:,0],x[:,1],c=y,s = 50,cmap = 'BrBG')

# %%
plt.scatter(x[:,1],x[:,0],c=y,s = 50,cmap = 'BrBG')

# %%
from mpl_toolkits.mplot3d import Axes3D
fig =plt.figure()

# %%
ax= Axes3D(fig)
ax

# %%
ax.set_xlabel('x1')
ax.set_ylabel('x2')
# Out:
# Text(0.5,0,'x2')

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig =plt.figure()
ax= Axes3D(fig)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('x3')
# Out:
# Text(0.5,0,'x3')

# %%
from mpl_toolkits.mplot3d import Axes3D
def start():
    fig =plt.figure()
    ax= Axes3D(fig)
    ax.set_xlabel('x1')
    ax.set_ylabel('x2')
    ax.set_zlabel('x3')
    ax.scatter(x[:,0],x[:,1], c=y, cmap='Spectral', s=50)
start()

# %%
r = np.exp(-(x[:, 0] ** 2 + x[:, 1] ** 2))
r
# Out:
# array([ 0.28329963,  0.98033205,  0.9856947 ,  0.34364581,  0.36218197,
#         0.98500046,  0.97627015,  0.31528517,  0.97333693,  0.96302857,
#         0.37061992,  0.3568999 ,  0.37349204,  0.97336315,  0.43943965,
#         0.97055314,  0.8536714 ,  0.97227374,  0.95295538,  0.46131192,
#         0.36175109,  0.29718862,  0.96573044,  0.41048665,  0.93792519,
#         0.30091221,  0.3691479 ,  0.9983242 ,  0.26607245,  0.30749856,
#         0.99637096,  0.92895012,  0.94998144,  0.36013988,  0.45334704,
#         0.99066315,  0.99775487,  0.96977301,  0.99973257,  0.97800216,
#         0.40168045,  0.37764055,  0.29341944,  0.99180553,  0.96597067,
#         0.97765268,  0.99925249,  0.43607047,  0.96571257,  0.34477406,
#         0.33046167,  0.97924916,  0.94585032,  0.99757772,  0.43478254,
#         0.97364791,  0.93439969,  0.40488846,  0.37856804,  0.9925035 ,
#         0.32722163,  0.23595063,  0.28795457,  0.27441472,  0.3867538 ,
# ...

# %%
x
# Out:
# array([[-1.09223076, -0.26130856],
#        [ 0.06817216, -0.12335517],
#        [ 0.02219904,  0.1179653 ],
#        [ 1.03150691,  0.06432163],
#        [-0.88520025,  0.48169393],
#        [ 0.02214509, -0.12092462],
#        [ 0.14100289, -0.06429716],
#        [ 0.52075312,  0.93973077],
#        [ 0.1184039 ,  0.11404163],
#        [-0.04149977,  0.18960478],
#        [ 0.06612267,  0.99408551],
#        [-0.64086619,  0.78714068],
#        [ 0.31669952,  0.9405105 ],
#        [-0.13413903, -0.09489342],
#        [ 0.6965944 ,  0.5805266 ],
#        [ 0.10475293,  0.13753525],
#        [-0.38513952,  0.09938052],
#        [-0.11835585,  0.11878459],
#        [ 0.20034215,  0.08972298],
#        [ 0.84253391, -0.25262121],
#        [-0.43519582, -0.90961723],
#        [-0.2556794 ,  1.07145523],
#        [ 0.15070519,  0.1102655 ],
#        [-0.50553996, -0.79676924],
#        [-0.01128832,  0.25289853],
#        [ 0.71535849, -0.83018006],
#        [-0.2331258 , -0.97067516],
# ...

# %%
d = np.sqrt((x[:, 0] ** 2 + x[:, 1] ** 2))
d
# Out:
# array([ 1.12305396,  0.1409395 ,  0.12003587,  1.03351042,  1.00777404,
#         0.12293563,  0.15497077,  1.07437318,  0.16439275,  0.19409328,
#         0.9962822 ,  1.0150369 ,  0.99240041,  0.1643108 ,  0.90678271,
#         0.17288471,  0.39775487,  0.16768389,  0.21951581,  0.8795913 ,
#         1.00836447,  1.10153904,  0.18673654,  0.94361638,  0.25315034,
#         1.09587258,  0.99827747,  0.04095372,  1.15064618,  1.08594884,
#         0.06029629,  0.27147787,  0.22652336,  1.01057547,  0.88943654,
#         0.09685408,  0.04740948,  0.17519489,  0.01635445,  0.14914222,
#         0.95503843,  0.98681936,  1.10731755,  0.0907096 ,  0.18606935,
#         0.15033565,  0.02734577,  0.91101669,  0.18678607,  1.03192343,
#         1.05226642,  0.14480733,  0.23594692,  0.0492465 ,  0.91263863,
#         0.16341826,  0.26048225,  0.95086469,  0.9855757 ,  0.08674525,
#         1.05693782,  1.20172072,  1.11577442,  1.13715203,  0.97466249,
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('x3')
# Out:
# Text(0.5,0,'x3')

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(x[:,0],x[:,1],d, c=y, cmap='Spectral', s=50)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('x3')
# Out:
# Text(0.5,0,'x3')

# %% [markdown]
# # sklearns KErnel

# %%
xy = SVC(kernel = 'rbf',C = 1E6)
xy.fit(x,y)
# Out:
# SVC(C=1000000.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(x[:,0],x[:,1],d, c=y, cmap='Spectral', s=50)

ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('x3')
# Out:
# Text(0.5,0,'x3')

# %%
xy = SVC(kernel = 'rbf',C = 1E6)
xy.fit(x,y)
# Out:
# SVC(C=1000000.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
plot_decision_regions(x, y, classifier=svm)
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-217-08650130d892> in <module>()
# ----> 1 plot_decision_regions(x, y, classifier=svm)
#       2 plt.legend(loc='upper left')
#       3 plt.tight_layout()
#       4 plt.show()
#
# NameError: name 'svm' is not defined

# %% [markdown]
# # SVC Parameters When Using RBF Kernel
#
#
# https://chrisalbon.com/machine_learning/support_vector_machines/svc_parameters_using_rbf_kernel/
#
#
# https://jakevdp.github.io/PythonDataScienceHandbook/05.07-support-vector-machines.html

# %%
from matplotlib.colors import ListedColormap

# %%
def versiontuple(v):
    return tuple(map(int, (v.split("."))))


def plot_decision_regions(x, y, classifier, test_idx=None, resolution=0.02):

    # setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = x[:, 0].min() - 1, x[:, 0].max() + 1
    x2_min, x2_max = x[:, 1].min() - 1, x[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.4, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=x[y == cl, 0], y=x[y == cl, 1],
                    alpha=0.8, c=cmap(idx),
                    marker=markers[idx], label=cl)

    # highlight test samples
    if test_idx:
        # plot all samples
        if not versiontuple(np.__version__) >= versiontuple('1.9.0'):
            X_test, y_test = X[list(test_idx), :], y[list(test_idx)]
            warnings.warn('Please update to NumPy 1.9.0 or newer')
        else:
            X_test, y_test = X[test_idx, :], y[test_idx]

        plt.scatter(X_test[:, 0],
                    X_test[:, 1],
                    c='',
                    alpha=1.0,
                    linewidths=1,
                    marker='o',
                    s=55, label='test set')

# %%
xy = SVC(kernel = 'linear',C = 1E6)
xy.fit(x,y)
plot_decision_regions(x, y, classifier=xy)
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
xy = SVC(kernel = 'rbf',C = 1E6)
xy.fit(x,y)
plot_decision_regions(x, y, classifier=xy)
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
xy = SVC(kernel = 'poly',C = 1E6)
xy.fit(x,y)
plot_decision_regions(x, y, classifier=xy)
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
clf = SVC(kernel='rbf', C=1E6)
clf.fit(x, y)

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(x[:,0],x[:,1],d, c=y, cmap='spring', s=50)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('r')

# %% [markdown]
# # Example: Face Recognition

# %%
from sklearn.datasets import fetch_lfw_people
faces = fetch_lfw_people(min_faces_per_person=60)
print(faces.target_names)
print(faces.images.shape)

# %%
fig, ax = plt.subplots(5, 6)
for i, axi in enumerate(ax.flat):
    axi.imshow(faces.images[i], cmap='bone')
    axi.set(xticks=[], yticks=[],
            xlabel=faces.target_names[faces.target[i]])

# %% [markdown]
# # Implemetation of SVM

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
read = pd.read_csv("/home/vikas/Downloads/data/mushrooms.csv")
read.head()

# %%
x = read.drop('class',axis = 1)
x.head()

# %%
y  = read['class']
y.head()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
cols = x.columns
X_enc = x.copy()
for col in cols:
    lb = LabelEncoder() # Shift + Tab
    X_enc[col] = lb.fit_transform(x[col].values)

# %%
X_enc

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
x_train,x_test,y_train,y_test = train_test_split(X_enc,y)

# %%
svc= SVC()
svc.fit(x_train,y_train)
svc.score(x_test,y_test)

# %%
# url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
# df = pd.read_csv(url, names=['sepal_lenght', 'sepal_width', 'petal_lenght', 'petal_width', 'class'])
# df.head(10)

# %%
x = df.drop('class',axis =1)
x.head()

# %%
y = df['class']
y.head()

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
x_train,x_test,y_train,y_test  = train_test_split(x,y)
svc = SVC()
svc.fit(x_train,y_train)
svc.predict(x_test)
svc.score(x_test,y_test)

# %%
r = pd.read_csv('/home/vikas/Downloads/data/food_inspections.csv',dtype = object)
r

# %%
z =r.fillna(0)

# %%
x= z.drop('Risk',axis = 1)
x

# %%
y = z['Risk']
y.head()

# %%
x

# %%
cols = x.columns
X_enc = x.copy()
for col in cols:
    lb = LabelEncoder() # Shift + Tab
    X_enc[col] = lb.fit_transform(x[col].values)

# %%
# X_ohe = pd.get_dummies(x) # Shift + Tab
# X_ohe.head()
