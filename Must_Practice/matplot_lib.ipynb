# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
mat = np.linspace(0,10,5)
mat1 = mat**2

# %%
mat
# Out:
# array([  0. ,   2.5,   5. ,   7.5,  10. ])

# %%
mat1
# Out:
# array([   0.  ,    6.25,   25.  ,   56.25,  100.  ])

# %%
plt.plot(mat,mat1,'kp--')

# %%
plt.xlabel('mat')
plt.ylabel('mat^2')
# Out:
# Text(0,0.5,'mat^2')

# %%
plt.title('Here is the graph ')
plt.plot(mat,mat1,'kp--')

# %%
plt.xlabel('mat')
plt.ylabel('mat^2')
plt.title('Here is the graph ')
plt.plot(mat,mat1,'kp--')

# %%
plt.plot(mat,mat1,np.arange(5),np.arange(5),'r')

# %%
plt.plot(mat,mat1,'r+')

# %%
plt.plot(mat,mat1,np.arange(5),'r*')

# %%
plt.plot(mat,mat1,np.arange(5),'r^')

# %%
plt.plot(mat,mat1,np.arange(5),'ro')

# %%
plt.plot(mat,mat1,'H')

# %%
plt.plot(mat,mat1,'1')

# %%
plt.plot(mat,mat1,'2')

# %%
plt.plot(mat,mat1,'3')

# %%
plt.plot(mat,mat1,'4')

# %%
plt.xlabel('mat')
plt.ylabel('mat*2')
plt.title('Graph is here')
plt.plot(mat,mat1,'g')
plt.plot(mat,mat1,'ro')

# %%
plt.xlabel('mat')
plt.ylabel('mat*2')
plt.title('Graph is here')
plt.plot(mat,mat1,'g^-')
plt.plot(mat,mat1,'ro--')

# %%
plt.xlabel('mat')
plt.ylabel('mat*2')
plt.title('Graph is here')

plt.plot(mat,mat1,'ro--')
plt.plot(mat,mat1,'g^-')

# %%
plt.xlabel('mat')
plt.ylabel('mat*2')
plt.title('Graph is here')

plt.plot(mat,mat1,'bo--')
#plt.plot(mat,mat1,'r^-')

# %%
plt.xlabel('mat')
plt.ylabel('mat*2')
plt.title('Graph is here')

plt.plot(mat,mat1,'bo--')
plt.plot(mat,mat1,'r^-')

# %% [markdown]
# # sub plot

# %%
plt.subplot(2,3,4)
plt.plot(mat,mat1,'r')
plt.subplot(2,3,3)
plt.plot(mat,mat1,'b')

# %%
plt.subplot(2,3,1)
plt.plot(mat,mat1,'r')
plt.subplot(2,3,6)
plt.plot(mat1,mat,'b')

# %%
plt.subplot(2,3,3)
plt.plot(mat,mat1,'r')
plt.subplot(2,3,4)
plt.plot(mat1,mat,'b')

# %%
plt.subplot(2,3,1)
plt.plot(mat,mat1,'b*-')
plt.subplot(2,5,4)
plt.plot(mat1,mat,'r--')

# %%
plt.subplot(2,3,1)
plt.plot(mat,mat1,'b*-')
plt.subplot(2,5,3)
plt.plot(mat1,mat,'r--')
plt.subplot(2,3,4)
plt.plot(mat1,mat,'g^-')

# %%
plt.subplot(2,3,1)
plt.plot(mat,mat1,'b*-')
plt.subplot(2,6,3)
plt.plot(mat1,mat,'r--')
plt.subplot(2,3,4)
plt.plot(mat1**2,mat**3,'g--')

# %%
fig = plt.figure()
fig

# %%
plt.plot(mat,mat1,'r')

# %%
fig = plt.figure()
axes1=fig.add_axes([0.1,0.1,0.3,0.3])
axes1.plot(mat,mat1,'r')

axes1.set_xlabel('X-axis1')
axes1.set_ylabel('Y-axis1')
axes1.set_title('Graph is below')
# Out:
# Text(0.5,1,'Graph is below')

# %%
fig = plt.figure()
axes1=fig.add_axes([0.1,0.1,0.7,0.7])
axes1.plot(mat,mat1,'r')

axes1.set_xlabel('X-axis1')
axes1.set_ylabel('Y-axis1')
axes1.set_title('Graph is below')
# Out:
# Text(0.5,1,'Graph is below')

# %%
fig = plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.3,0.5,0.2,0.3])
axes1.plot(mat,mat1,'r')

axes1.set_xlabel('X-axis1')
axes1.set_ylabel('Y-axis1')
axes1.set_title('Graph is below')
axes2.set_xlabel('X-axis2')
axes2.set_ylabel('Y-axis2')
axes2.set_title('inner title')
axes2.plot(mat,mat1,'b--')

# %%
fig = plt.figure()
fig

# %%
axes = plt.subplots(nrows= 2,ncols= 3)

# %%
fig,axes = plt.subplots(nrows= 2,ncols= 3)

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3238537cc0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3238347e48>]], dtype=object)

# %%
for i in axes:
    for j in i:
        j.plot(mat,mat1,'r')
        j.set_xlabel('X-axis')
        j.set_ylabel('Y-axis')
        j.set_title('Graph')
fig

# %%
axes = plt.subplots()

# %%
axes = plt.subplots(nrows =1,ncols = 2)

# %%
x ,axes = plt.subplots(nrows = 1,ncols = 2)
for i in axes:
    i.set_xlabel('x')
    i.set_ylabel('y')
    i.set_title('Graph')
    i.plot(mat,mat1,'r--')
    
x

# %%
x ,axes = plt.subplots(nrows = 1,ncols = 2)
for i in axes:
    i.set_xlabel('x')
    i.set_ylabel('y')
    i.set_title('Graph')
    i.plot(mat,mat1,'r--')
    
x

x.tight_layout()

# %%
fig  = plt.subplots(figsize = (10,5),dpi = 100)

# %%
fig,axes = plt.subplots(figsize = (8,4))

# %%
fig,axes = plt.subplots(figsize = (8,4))
axes.set_xlabel('X-axis')
axes.set_ylabel('Y-axis')
axes.set_title('Graph is here')
axes.plot(mat,mat1,'g--')

# %%
fig.savefig('/home/vikas/Downloads/grp.png')

# %%
fig.savefig('/home/vikas/Downloads/grp21.png',dpi = 33)

# %%
i.set_title('Title')
# Out:
# Text(0.5,1,'Title')

# %%
i.set_title('Title')

i.set_xlabel('MAT')
i.set_ylabel('MAT**2')
plt.plot(mat,mat1,'r')

# %%
#

# %%
plt.plot(mat, mat**3, label="x**2")
plt.plot(mat1, mat1**2, label="x**3")
plt.legend()

# %%
plt.plot(mat)

# %%
plt.plot(mat1)

# %%
plt.plot(mat)
plt.plot(mat1)

# %%
plt.plot(mat,label = 'x')
plt.plot(mat1,label = 'x**2')
plt.legend()

# %%
fig  = plt.subplots(figsize = (10,5),dpi = 100)

# %%
import matplotlib as mpl, matplotlib.pyplot as plt
print(mpl.__version__)
# Out:
# 2.1.0

# %%
fig  = plt.subplots(figsize = (10,5))

# %%
fig ,a  = plt.subplots(figsize = (10,5),dpi =100)

# %%
a.plot(mat,mat+1, color="red", linewidth=0.25)
fig# figure

# %%
a #####adress

# %%
a.plot(mat, mat+2, color="red", linewidth=0.50)
fig

# %%
a.plot(mat, mat+3, color="red", linewidth=1.00)
fig

# %%
a.plot(mat, mat+4, color="red", linewidth=2)
fig

# %%
a.plot(mat,mat+5,color = 'yellow',lw= 3,linestyle= '-')
fig

# %%
a.plot(mat, mat+6, color="yellow", lw=3, ls='-.')
fig

# %%
a.plot(mat, mat+7, color="yellow", lw=3, ls=':')
fig

# %%
#a.plot(mat,mat8,color= 'yellow',lw = 3,linestyle= '')
line, = a.plot(mat, mat+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10])
fig

# %%
fig,b = plt.subplots(figsize= (5,5),dpi = 100)

# %%
b.plot(mat,color = 'red',linestyle = '-',lw = 3)
fig

# %%
v = b.plot(mat,mat+1,color = 'red',linestyle = '-',lw = 1,marker = 'o',markersize = 3)
fig

# %%
from matplotlib import pyplot as plt

# %%
a,b = plt.subplots(1,3,figsize=(12,4),dpi= 100)

# %%
a,b = plt.subplots(1,3,figsize=(12,4),dpi= 100)
b[0].plot(mat,mat**2)
b[0].plot(mat,mat**3)

# %%
a,b = plt.subplots(1,3,figsize=(12,4),dpi= 100)
b[0].plot(mat,mat**2,mat,mat**3)
b[0].set_title('First Graph')
# Out:
# Text(0.5,1,'First Graph')

# %%
a,b = plt.subplots(1,3,figsize=(12,4),dpi= 100)
b[0].plot(mat,mat**2,mat,mat**3)
b[0].set_title('First Graph')
b[1].plot(mat,mat**3,mat,mat**2)
b[1].set_title('Second Graph')
# Out:
# Text(0.5,1,'Second Graph')

# %%
a,b = plt.subplots(1,3,figsize=(12,4),dpi= 100)
b[0].plot(mat,mat**2,mat,mat**3)
b[0].set_title('First Graph')
b[1].plot(mat,mat**3,mat,mat**2)
b[1].set_title('Second Graph')
b[2].plot(mat,mat**2,mat,mat**3)
b[2].set_title('Third Graph')
# Out:
# Text(0.5,1,'Third Graph')

# %%
plt.scatter(np.arange(10),np.random.randn(5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-775eb23dc7e8> in <module>()
# ----> 1 plt.scatter(np.arange(10),np.random.randn(5))
#
# ~/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3355                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3356                          linewidths=linewidths, verts=verts,
# -> 3357                          edgecolors=edgecolors, data=data, **kwargs)
#    3358     finally:
#    3359         ax._hold = washold
#
# ~/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# ...

# %%
plt.scatter(np.arange(10),np.random.randn(10))

# %%
from random import sample

# %%
data = sample(range(0,10),5)
data
# Out:
# [2, 0, 1, 6, 8]

# %%
plt.hist(data)
# Out:
# (array([ 1.,  1.,  1.,  0.,  0.,  0.,  0.,  1.,  0.,  1.]),
#  array([ 0. ,  0.8,  1.6,  2.4,  3.2,  4. ,  4.8,  5.6,  6.4,  7.2,  8. ]),
#  <a list of 10 Patch objects>)

# %%
plt.boxplot(data,vert=True,patch_artist=True);
