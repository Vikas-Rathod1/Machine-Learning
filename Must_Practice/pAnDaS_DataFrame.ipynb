# %% [markdown]
# ####  Befor of this u  know about how to create datframe and insert colname and values in it
# https://datatofish.com/add-column-dataframe/

# %% [markdown]
# # Basic Of Pandas_DataFrame

# %%
import pandas as pd 
import numpy as np

# %%
a = {"name":"vikas",
    "age":24,
     "hobby":"playing chess"}
b = {"name":"Harshal",
     "age":23,
     "hobby":"playing cricket"}
c = {"name":"akash",
     "age":23,
     "hobby":"playing something"}

# %%
c
# Out:
# {'name': 'akash', 'age': 23, 'hobby': 'playing something'}

# %%
pd.DataFrame([a,b,c])
# Out:
#    age              hobby     name
# 0   24      playing chess    vikas
# 1   23    playing cricket  Harshal
# 2   23  playing something    akash

# %%
# if i want to change index then i wiill use like this
pd.DataFrame([a,b,c],index=['p1','p2','p3'])
# Out:
#     age              hobby     name
# p1   24      playing chess    vikas
# p2   23    playing cricket  Harshal
# p3   23  playing something    akash

# %%
rd = np.random.randint(10,100,25).reshape(5,5)

# %%
rd
# Out:
# array([[28, 29, 38, 60, 50],
#        [26, 44, 88, 35, 23],
#        [79, 37, 81, 63, 11],
#        [65, 19, 33, 22, 19],
#        [35, 63, 63, 37, 90]])

# %%
# if i want to give the index and label to the array then i will do like this
import pandas as pd
v = pd.DataFrame(rd,index=['n1','n2','n3','n4','n5'],columns=[1,2,3,4,5])

# %%
v
# Out:
#      1   2   3   4   5
# n1  28  29  38  60  50
# n2  26  44  88  35  23
# n3  79  37  81  63  11
# n4  65  19  33  22  19
# n5  35  63  63  37  90

# %% [markdown]
# # Advanced Data Frame in Pands

# %%
# here we ll perform operations on dataste i.e csv files 
#lets start the Session

# %%
import numpy as np 
import pandas as pd

# %%
read= pd.read_csv("/home/vikas/Downloads/data/train.csv")

# %%
read
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
v = read[['Name', 'Sex', 'Ticket', 'Cabin']] #here is the magic , bcz we r used list in list
#(when we use ths then its returns the multiple coluns abd if we use single then it return Series) 
#lets check its out below
v.head()
# Out:
#                                                 Name     Sex  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin
# 0         A/5 21171   NaN
# 1          PC 17599   C85
# 2  STON/O2. 3101282   NaN
# 3            113803  C123
# 4            373450   NaN

# %%
v = read['Name'].head() #clear to all of u gyz

# %%
v
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
#read.select_dtypes(include='object')
read
#read.select_dtypes(include = 'object')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
r = read.select_dtypes(include  = ['object', 'int64']).head()
r
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    male      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                             Heikkinen, Miss. Laina  female      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                           Allen, Mr. William Henry    male      0      0
#
#              Ticket Cabin Embarked
# 0         A/5 21171   NaN        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282   NaN        S
# 3            113803  C123        S
# 4            373450   NaN        S

# %%
r.filter(like= 'Name') # here it gives the labes i.e the name we r given to like.. then it check wether this given
#strng ir present if present then it returns those labels
# Out:
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry

# %%
r.filter(regex = '\w') # u can use this link to know more about regex
#The *filter* method allows columns to be searched through **regular expressions** with the *regex* parameter.
#To know more about regex [visit this website](https://regexone.com/)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    male      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                             Heikkinen, Miss. Laina  female      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                           Allen, Mr. William Henry    male      0      0
#
#              Ticket Cabin Embarked
# 0         A/5 21171   NaN        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282   NaN        S
# 3            113803  C123        S
# 4            373450   NaN        S

# %%
read
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
read.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# 5          False     False   False  False  False   True  False  False   False
# 6          False     False   False  False  False  False  False  False   False
# 7          False     False   False  False  False  False  False  False   False
# 8          False     False   False  False  False  False  False  False   False
# 9          False     False   False  False  False  False  False  False   False
# 10         False     False   False  False  False  False  False  False   False
# ...

# %%
read.min()
# Out:
# PassengerId                      1
# Survived                         0
# Pclass                           1
# Name           Abbing, Mr. Anthony
# Sex                         female
# Age                           0.42
# SibSp                            0
# Parch                            0
# Ticket                      110152
# Fare                             0
# dtype: object

# %%
#read['Survived'].min()
read.min()
# Out:
# PassengerId                      1
# Survived                         0
# Pclass                           1
# Name           Abbing, Mr. Anthony
# Sex                         female
# Age                           0.42
# SibSp                            0
# Parch                            0
# Ticket                      110152
# Fare                             0
# dtype: object

# %%
#read['Ticket'].min()
read['Age'].min()
# Out:
# 0.42

# %%
read.std()
# Out:
# PassengerId    257.353842
# Survived         0.486592
# Pclass           0.836071
# Age             14.526497
# SibSp            1.102743
# Parch            0.806057
# Fare            49.693429
# dtype: float64

# %%
read.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
read.max()
# Out:
# PassengerId                            891
# Survived                                 1
# Pclass                                   3
# Name           van Melkebeke, Mr. Philemon
# Sex                                   male
# Age                                     80
# SibSp                                    8
# Parch                                    6
# Ticket                           WE/P 5735
# Fare                               512.329
# dtype: object

# %%
read['Pclass'].max()
# Out:
# 3

# %%
# it return the no of missing values from each columns
read.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
read.isnull().sum().sum() #missing values from the dataframe
# Out:
# 866

# %% [markdown]
# # Working with Operators

# %%
read_frame = pd.read_csv("/home/vikas/Downloads/data/college.csv") #,index_col = 'CITY'

# %%
type(read_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
read_frame = pd.read_csv("/home/vikas/Downloads/data/college.csv",index_col = "vikas")
# error cause bcz 'vikas' is not present as label in the data frame
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-8e1678f3659b> in <module>
# ----> 1 read_frame = pd.read_csv("/home/vikas/Downloads/data/college.csv",index_col = "vikas")
#       2 # error cause bcz 'vikas' is not present as label in the data frame
#
# ...

# %%
r =read_frame

# %%
r

# %%
rq = r.filter(like='UGDS_').head(20)
rq

# %%
type(rq)

# %%
rq  + 10

# %%
type(r)

# %%
r.head(20)

# %%
r + 10 #  error occured bcz r has a string in it but rq has homogenous values all numbers

# %%
(rq*1000).head()

# %% [markdown]
# # Compare with mising values

# %%
rd == rd

# %%
None ==  None

# %%
r

# %%
read.count()

# %%
rq.count(axis = 1)

# %% [markdown]
# # Indexing

# %%
import pandas as pd

# %%
read_ = pd.read_csv("/home/vikas/Downloads/data/train.csv")

# %%
read_.head(10)

# %% [markdown]
# # Set index operation

# %%
read_.set_index("Name").head()

# %% [markdown]
# # Remaming of col and index

# %%
col_name = {'Name':'Pname','Sex':'Gender','Cabin':'C_Cabin'}

read_.rename(columns = col_name).head()

# %% [markdown]
# # Reset operation

# %%
read_.reset_index().head()

# %% [markdown]
# # Creating and deleting  col and row

# %%
read_.head()

# %%
read_['new_col']='vikas'

# %%
read_.head()

# %% [markdown]
# @@@@@@@@@@@@ CANCATINATION OF SAME DTYPE OF LABES I.E COLUMN

# %% [markdown]
# mix_col = read_['Ticket_Fare_Cabin'] = (read_['PassengerId']+
#                                  read_['Survived']+read_['Pclass'])

# %%
mix_col.head() #here addtion as takes alce of digits of all tree col

# %%
mix_col.mean()

# %%
read_.head(10)

# %%
read_.drop(['PassengerId','Name'],axis = 1,inplace= True)

# %%
read_.head()

# %% [markdown]
# # .loc

# %%
import pandas as pd
read_ = pd.read_csv("/home/vikas/Downloads/data/train.csv")

# %%
read_.head(10)

# %%
read_.loc[0] #### it display the row which we  provided in list

# %%
read_['Name'].head(10) ## here is display the column

# %%
read_.loc[0:5] # slicing on  rows of dtaframe

# %%
read_.loc[0:20:2] ## step size is 2    here u can use any number whatever u  want

# %% [markdown]
# # Select the rows and columns simulteneously

# %% [markdown]
# xyz.loc[[row_selection],[column_selction]]

# %%
read_.loc[[0,1,2,6],['Name','Sex','Ticket']]

# %%
read_.loc[1:20:4,['Name','Age','Cabin']] ## here 4 is step size

# %% [markdown]
# # Slicing

# %%
read_.loc[5:,'Sex':].head(10)##### index start from 5 and col name from Sex

# %% [markdown]
# # Select all rows and Some Columns and below for Columns

# %%
read_.loc[:,['Name','Age','Cabin','Sex']]

# %%
read_.loc[[1,2,3,6,4,7,9,12],:] ######## some rows and all Columns

# %%
read_.loc[[1,2,3,6,4,7,9,12]]

# %%
###If i want to  to assign var for row and col and then call them
col_name= ['Name','Sex','Parch','Age']
row_name= [2,4,5,3]
read_.loc[row_name,col_name]
# here is one twist is if i call first Col_name Nd then row_name it will cause error.... undurstand why is happened

# %% [markdown]
# # .iloc on dataframe

# %%
read_.head(20)

# %%
read_.iloc[0] ## oth index

# %%
read_.iloc[0:6] ## rows

# %%
read_.iloc[:,[2,3,4,6,2,8]].head(20) ## here 2 is repeated then also print that column

# %%
s = read_['Name'].head(20)
s

# %%
s.iloc[9]

# %%
s.iloc[0:20:3]

# %%
read_.iloc[20]

# %%
read_.head(20)

# %%
read_.index

# %%
list(read_.index)

# %%
list(range(20))

# %%
read_

# %%
read_.iloc[[1,3,5,7,4]]
